# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
data_durchschnitt_verbrauch = pd.read_csv('durchschnitt_verbrauch.csv', sep=';')
data_ladesaeulen = pd.read_csv('ladesaeulen.csv')
data_neuzulassung = pd.read_csv('neuzulassung.csv', sep=';')
data_pkw_bestand_kraftstoffart = pd.read_csv('pkw_bestand_kraftstoffart_neu.csv', sep=';')
data_neuzulassung_kraftstoffart = pd.read_csv('pkw_neuzulassung_kraftstoffart.csv', sep=';')
data_gebrauchtwagen = pd.read_csv('gebrauchtwagen.csv')

# %%
plt.figure(figsize=(18, 12))
sns.lineplot(data=data_durchschnitt_verbrauch, x='Jahr', y='Benzin', label='Benzin')
sns.lineplot(data=data_durchschnitt_verbrauch, x='Jahr', y='Diesel', label='Diesel')
sns.lineplot(data=data_durchschnitt_verbrauch, x='Jahr', y='kombiniert', label='Kombiniert')

plt.title('Verbrauchstrends nach Jahr')
plt.xlabel('Jahr')
plt.ylabel('Verbrauch')
plt.legend(title='Kraftstofftyp')
plt.grid(True)
plt.show()

# %%
data_gebrauchtwagen.value_counts
# Out:
# <bound method DataFrame.value_counts of         Unnamed: 0       brand              model  color registration_date  \
# 0                0  alfa-romeo     Alfa Romeo GTV    red           10/1995
# 1                1  alfa-romeo     Alfa Romeo 164  black           02/1995
# 2                2  alfa-romeo  Alfa Romeo Spider  black           02/1995
# 3                3  alfa-romeo  Alfa Romeo Spider  black           07/1995
# 4                4  alfa-romeo     Alfa Romeo 164    red           11/1996
# ...            ...         ...                ...    ...               ...
# 251074      251074       volvo         Volvo XC40  white           04/2023
# 251075      251075       volvo         Volvo XC90  white           03/2023
# 251076      251076       volvo          Volvo V60  white           05/2023
# 251077      251077       volvo         Volvo XC40  white           05/2023
# 251078      251078       volvo         Volvo XC40   gold           03/2023
#
# ...
